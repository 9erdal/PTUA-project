# %% [markdown]
# # Web scraping Oslo bike count data

# %%
# install the packages if you don't have them.
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install tqdm
# !pip install watermark
! pip install folium
# Out:
# Requirement already satisfied: requests in c:\users\bruker\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bruker\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruker\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bruker\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruker\anaconda3\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: beautifulsoup4 in c:\users\bruker\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bruker\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: pandas in c:\users\bruker\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bruker\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bruker\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bruker\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bruker\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\bruker\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\bruker\anaconda3\lib\site-packages (4.66.5)
# Requirement already satisfied: colorama in c:\users\bruker\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: watermark in c:\users\bruker\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: ipython>=6.0 in c:\users\bruker\anaconda3\lib\site-packages (from watermark) (8.27.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\bruker\anaconda3\lib\site-packages (from watermark) (7.0.1)
# Requirement already satisfied: setuptools in c:\users\bruker\anaconda3\lib\site-packages (from watermark) (75.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\bruker\anaconda3\lib\site-packages (from importlib-metadata>=1.4->watermark) (3.17.0)
# Requirement already satisfied: decorator in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (5.14.3)
# Requirement already satisfied: colorama in c:\users\bruker\anaconda3\lib\site-packages (from ipython>=6.0->watermark) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\bruker\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\bruker\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark) (0.2.5)
# Requirement already satisfied: executing in c:\users\bruker\anaconda3\lib\site-packages (from stack-data->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\bruker\anaconda3\lib\site-packages (from stack-data->ipython>=6.0->watermark) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\bruker\anaconda3\lib\site-packages (from stack-data->ipython>=6.0->watermark) (0.2.2)
# Requirement already satisfied: six in c:\users\bruker\anaconda3\lib\site-packages (from asttokens->stack-data->ipython>=6.0->watermark) (1.16.0)
# Requirement already satisfied: folium in c:\users\bruker\anaconda3\lib\site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\bruker\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\bruker\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\bruker\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\bruker\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\bruker\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bruker\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bruker\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruker\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bruker\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruker\anaconda3\lib\site-packages (from requests->folium) (2024.12.14)

# %%
# Loading library
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import ast
from pandas import json_normalize
from tqdm import tqdm
import folium

# %%
response = requests.get("https://data.eco-counter.com/ParcPublic/?id=3936") # Sends an HTTP GET request to the target URL
response.raise_for_status() # Checks the status code of the HTTP response

# If the HTTP request was successful (i.e., the status code is in the 200–299 range), no exception information will be returned. 
# If the server returns an error code (i.e., the status code is 400 or above), raise_for_status() will raise an HTTPError.

# %%
html_content = response.text #  get the body of the response, i.e., the HTML content of the page, as a string
soup = BeautifulSoup(html_content, 'html.parser') # parsing HTML content

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title></title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="styles/normalize.css" rel="stylesheet"/>
# <link href="styles/leaflet.css" rel="stylesheet">
# <!-- <link rel="stylesheet" href="styles/daterangepicker.css">  -->
# <link href="styles/daterangepicker.min.css" rel="stylesheet"/>
# <link href="styles/jquery-ui.min.css" rel="stylesheet"/>
# <link href="styles/main.css" rel="stylesheet"/>
# <link href="styles/plugins.css" rel="stylesheet"/>
# <link href="styles/font-awesome.min.css" rel="stylesheet"/>
# <link href="styles/eco-font.css" rel="stylesheet"/>
# <script src="js/vendor/modernizr-2.6.2.min.js"></script>
# </link></head>
# <body>
# <!--[if lt IE 7]>
#             <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> or <a href="http://www.google.com/chromeframe/?redirect=true">activate Google Chrome Frame</a> to improve your experience.</p>
#         <![endif]-->
# <header>
# <section id="mainTitleBar">
# <div id="mainHeaderLeft">
# <img id="imgLogo"/>
# </div>
# <div id="mainHeaderCenter">
# <p id="domaineName"></p>
# <div id="counterNumber"><span id="counterNumberValue"></span> <span data-label="labelCompteurs"></span></div>
# </div>
# <div id="mainHeaderRight">
# <div id="options">
# <!-- ICI LE FILTRAGE -->
# <!-- <a data-reveal-id="popup" href="#"><p id="test" data-label="labelFiltre"></p></a> -->
# <!-- ############### -->
# <select id="languageSelect" name="languageSelect">
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="en">English</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="us">English US</option>
# <option data-description="" data-imagesrc="assets/icons/fr.png" value="fr">FranÃ§ais</option>
# <option data-description="" data-imagesrc="assets/icons/de.png" value="de">Deutsch</option>
# <option data-description="" data-imagesrc="assets/icons/es.png" value="es">EspaÃ±ol</option>
# <option data-description="" data-imagesrc="assets/icons/es.png" value="ca">CatalÃ </option>
# <option data-description="" data-imagesrc="assets/icons/sv.png" value="sv">Svensk</option>
# <option data-description="" data-imagesrc="assets/icons/no.png" value="no">Norsk</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="jp">æ¥æ¬èª</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="pt">PortuguÃªs</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="hu">Magyar</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="cn">ä¸­å½</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="tr">TÃ¼rkÃ§e</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="et">Eesti</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="it">Italiano</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="pl">Polska</option>
# <option data-description="" data-imagesrc="assets/icons/uk.png" value="is">Ãslenska</option>
# </select>
# </div>
# <div id="shareDiv">
# <div><img class="share-mail" src="assets/icons/mail.png"/></div>
# <div><img class="share-twitter" src="assets/icons/twitter.png"/></div>
# <div><img class="share-facebook" src="assets/icons/facebook.png"/></div>
# </div>
# </div>
# </section>
# </header>
# <section class="rightBarOpen" id="rightBar">
# <div class="subHeader1">
# <img src="assets/icons/calendar_icon.png" style="max-width:46px"/>
# <div id="periodDiv">
# <p class="wrapperDate">
# <span data-label="labelFrom" id="lblFrom"></span> <span id="txtDebut"></span>
# </p>
# <p class="wrapperDate">
# <span data-label="labelTo" id="lblTo"></span> <span id="txtFin"></span> <i class="fa fa-calendar select-period-link"></i>
# </p>
# </div>
# </div>
# <div class="subHeader2">
# <div id="headerChart"></div>
# <div id="expandChartDiv">
# <a href="#"><span><i class="fa fa-angle-down expandChartIcon"></i> <span class="expandChartIcon" data-label="labelMore" id="labelMoreChart"></span></span></a>
# </div>
# </div>
# <div class="subHeader3">
# <p>
# <span class="title" data-label="labelTotal"></span>
# </p>
# <p>
# <span id="totalValue"></span>
# </p>
# </div>
# <div class="subHeader4">
# <p><!-- class="TotalCountsInfo"> -->
# <span class="title" data-label="labelMoyenneJour"></span>
# </p>
# <p>
# <span id="averageValue"></span>
# </p>
# </div>
# </section>
# <!-- MAP -->
# <div id="map_canvas"></div>
# <div id="legende-drc">
# <p>
# <img src="assets/markers/drc/green_pt.png"/> <span>DonnÃ©es validÃ©es</span> <span id="legendeNbValide"></span>
# </p>
# <p>
# <img src="assets/markers/drc/orange_pt.png"/> <span>En attente de validation</span> <span id="legendeNbNonValide"></span>
# </p>
# </div>
# <a href="http://www.eco-compteur.com"><img class="logo_eco" src="assets/logos/LOGO_ECO_COUNTER.png"/></a>
# <section class="infoWindow infoWindowClose" id="info_window_canvas">
# <div id="infoContainer">
# <div id="infoHeader">
# <div class="cadrePratique">
# <img id="imgPratique"/>
# <i class="eco" id="iconPratique"></i>
# </div>
# <div id="stats">
# <a href="#"><img class="closeButton" height="32" onclick="showInfoWindow()" src="assets/icons/close.png" width="32"/></a>
# <p id="txt_nom"></p>
# <p class="infoFooter">
# <a data-label="pagePublique" id="lienPublic" target="_blank"></a>
# </p>
# <p id="public-message"></p>
# <div class="chiffres">
# <div class="chiffresInfos" id="lastDay">
# <span class="chiffresInfosTitle" data-label="labelLastDayCounter"></span>
# <span class="chiffresInfosValue" id="lastDayValue"></span>
# </div>
# <div class="chiffresInfos">
# <span class="chiffresInfosTitle" data-label="labelMoyDCounter"></span>
# <span class="chiffresInfosValue" id="moyDValue"></span>
# </div>
# <div class="chiffresInfos">
# <span class="chiffresInfosTitle" data-label="labelTotalCounter"></span>
# <span class="chiffresInfosValue" id="totalCounterValue"></span>
# </div>
# </div>
# </div>
# </div>
# <div id="details">
# <div id="description">
# <p id="txt_description"></p>
# </div>
# <hr class="hRule"/>
# <!-- AJOUT SELECTION TYPE GRAPHIQUE -->
# <nav id="counterDataPeriod">
# <ul>
# <li id="liSelectedData"><a href="#"><span data-label="labelGraphAllData" id="counterSelectedData"></span><div id="down-triangle"></div></a>
# <ul>
# <li><a class="counterDataChoice" data-label="labelGraphAllData" href="#" id="counterAllData">All Data</a></li>
# <li><a class="counterDataChoice" data-label="labelGraphLastData" href="#" id="counterLastData">Last 30 data days</a></li>
# </ul>
# </li>
# </ul>
# </nav>
# <div id="counterChart"></div>
# <div id="counterDataInterval" style="color:#fff; text-align:center; font-size: 0.8em">
# <div class="div-radio" id="div-radio-daily"><input checked="" id="radioDaily" name="dataInterval" type="radio" value="4"/> <label class="radio-label" for="radioDaily"><span class="radio-tick"></span><span data-label="labelGraphIntervalDaily"></span></label></div>
# <div class="div-radio" id="div-radio-weekly"><input id="radioWeekly" name="dataInterval" type="radio" value="5"/> <label class="radio-label" for="radioWeekly"><span class="radio-tick"></span><span data-label="labelGraphIntervalWeekly"></span></label></div>
# <div class="div-radio" id="div-radio-monthly"><input id="radioMonthly" name="dataInterval" type="radio" value="6"/> <label class="radio-label" for="radioMonthly"><span class="radio-tick"></span><span data-label="labelGraphIntervalMonthly"></span></label></div>
# </div>
# <hr class="hRule"/>
# <div id="slider"></div>
# </div>
# </div>
# </section>
# <div class="ui-widget-content" id="section_map_alt">
# <div id="map_alt"></div>
# <div class="ui-resizable-handle ui-resizable-ne" id="negrip"></div>
# </div>
# <section class="reveal-modal" id="progressBar">
# <img src="assets/logos/LOGO_ECO_COUNTER.png"/>
# <div class="progress-bar green stripes">
# <span style="width: 100%"></span>
# </div>
# <h3 data-label="labelChargement" id="labelChargement"></h3>
# <h3 data-label="labelLoadingError" id="labelLoadingError"></h3>
# </section>
# <section class="reveal-modal large" id="full-chart-modal" style="height: 80%; ">
# <h3 data-label="labelTitreGraphiqueComplet"></h3><span class="subtitle"></span>
# <div id="full-chart-wrapper-div" style="overflow-y:scroll; width: 100%">
# <div id="full-chart-div" style="width: 100%">
# </div>
# </div>
# </section>
# <!--[if lt IE 9]> <script src="js/vendor/excanvas.js"></script><![endif]-->
# <script src="js/vendor/jquery.min.js"></script>
# <script src="js/vendor/leaflet.js"></script>
# <script src="js/vendor/leaflet-plugins-1.2.1/layer/tile/Google.js"></script>
# <script src="js/vendor/jqplot/jquery.jqplot.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.barRenderer.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.categoryAxisRenderer.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.pointLabels.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.dateAxisRenderer.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.canvasTextRenderer.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.canvasAxisTickRenderer.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.highlighter.min.js"></script>
# <script src="js/vendor/jqplot/jqplot.cursor.min.js"></script>
# <script src="js/vendor/slidesjs/slides.min.jquery.js"></script>
# <script src="js/vendor/moment.min.js"></script>
# <script src="js/vendor/jquery.mousewheel.min.js"></script>
# <script src="js/vendor/jquery.mCustomScrollbar.js"></script>
# <script src="js/vendor/jquery.reveal.js"></script>
# <script src="js/vendor/jquery-ui.min.js"></script>
# <script src="js/vendor/jquery.daterangepicker.min.js"></script>
# <script src="js/vendor/highcharts.js"></script>
# <script src="js/plugins.js"></script>
# <script src="js/config.js"></script>
# <script src="js/main.min.js?t=1697100193690"></script>
# <script src="js/vendor/log.min.js"></script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-6688181-5"></script>
# <script>
# 		  window.dataLayer = window.dataLayer || [];
# 		  function gtag(){dataLayer.push(arguments);}
# 		  gtag('js', new Date());
#
# 		  gtag('config', 'UA-6688181-5');
# 		</script>
# <script type="text/javascript">
#
#           var appName = "Parc publique";
#           var appVersion = "2.0";
#           // Initialisation de l'application, avec le nom et version de l'application
#           Log.init({
#               application: appName,
#               version_application: appVersion
#           });
#           // onLoad: enregistement de la visite
#           $(function(){
#               Log.startVisit({});
#           });
# 		</script>
# </body>
# </html>

# %%
soup.find_all("script")
# Out:
# [<script src="js/vendor/modernizr-2.6.2.min.js"></script>,
#  <script src="js/vendor/jquery.min.js"></script>,
#  <script src="js/vendor/leaflet.js"></script>,
#  <script src="js/vendor/leaflet-plugins-1.2.1/layer/tile/Google.js"></script>,
#  <script src="js/vendor/jqplot/jquery.jqplot.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.barRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.categoryAxisRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.pointLabels.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.dateAxisRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.canvasTextRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.canvasAxisTickRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.highlighter.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.cursor.min.js"></script>,
#  <script src="js/vendor/slidesjs/slides.min.jquery.js"></script>,
#  <script src="js/vendor/moment.min.js"></script>,
#  <script src="js/vendor/jquery.mousewheel.min.js"></script>,
#  <script src="js/vendor/jquery.mCustomScrollbar.js"></script>,
#  <script src="js/vendor/jquery.reveal.js"></script>,
#  <script src="js/vendor/jquery-ui.min.js"></script>,
#  <script src="js/vendor/jquery.daterangepicker.min.js"></script>,
#  <script src="js/vendor/highcharts.js"></script>,
#  <script src="js/plugins.js"></script>,
#  <script src="js/config.js"></script>,
#  <script src="js/main.min.js?t=1697100193690"></script>,
#  <script src="js/vendor/log.min.js"></script>,
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-6688181-5"></script>,
#  <script>
#  		  window.dataLayer = window.dataLayer || [];
#  		  function gtag(){dataLayer.push(arguments);}
#  		  gtag('js', new Date());
#
#  		  gtag('config', 'UA-6688181-5');
#  		</script>,
#  <script type="text/javascript">
#
#            var appName = "Parc publique";
#            var appVersion = "2.0";
#            // Initialisation de l'application, avec le nom et version de l'application
#            Log.init({
#                application: appName,
#                version_application: appVersion
#            });
#            // onLoad: enregistement de la visite
#            $(function(){
#                Log.startVisit({});
#            });
#  		</script>]

# %%
def find_target_script(soup):
    scripts = soup.find_all('script')
    for script in scripts:
        if script.string and 'var prices =' in script.string:
            return script.string
    return None

# %%
target_script_content = find_target_script(soup)

# %%
print(target_script_content)
# Out:
# None

# %%
# A function to extract the JavaScript arrays as strings and then convert them into Python lists. 
def extract_js_array(target_script_content, variable_name):
    # Find the target array
    pattern = re.compile(r"var\s+" + re.escape(variable_name) + r"\s*=\s*(\[[^\]]*\]);", re.DOTALL)
    match = pattern.search(target_script_content)
    if match:
        array_str = match.group(1)
        array_data = ast.literal_eval(array_str)
        return array_data
    else:
        print(f"{variable_name} not found")
    return None

# Apply this function to your target variables (e.g., prices, bedrooms, latitudes, longitudes etc.) to extract different information related to housing.
variables = [
    'prices', 'bedrooms', 'bathrooms', 'students', 'nonStudents',
    'dss', 'pets', 'isstudio', 'isshared', 'furnished', 'hasVideo',
    'propertyTypes', 'hoursLive', 'gardens', 'parkings', 'bills',
    'availableFrom', 'minimumTenancy', 'PROPERTYIDS', 'PROPERTYLISTLATITUDES',
    'PROPERTYLISTLONGITUDES'
]

data = {}
for var in variables:
    data[var] = extract_js_array(target_script_content, var)

# Organize it into a pandas DataFrame. 
property_info = pd.DataFrame(data) 

property_info.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 25
#      23 data = {}
#      24 for var in variables:
# ---> 25     data[var] = extract_js_array(target_script_content, var)
#      27 # Organize it into a pandas DataFrame.
#      28 property_info = pd.DataFrame(data)
#
# Cell In[77], line 5, in extract_js_array(target_script_content, variable_name)
#       2 def extract_js_array(target_script_content, variable_name):
#       3     # Find the target array
#       4     pattern = re.compile(r"var\s+" + re.escape(variable_name) + r"\s*=\s*(\[[^\]]*\]);", re.DOTALL)
# ----> 5     match = pattern.search(target_script_content)
#       6     if match:
#       7         array_str = match.group(1)
#
# TypeError: expected string or bytes-like object, got 'NoneType'

# %%
test = pd.DataFrame(extract_js_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1484\3042513619.py in ?()
# ----> 1 test = pd.DataFrame(extract_js_array)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %% [markdown]
# ## Try different HTML

# %%
response2 = requests.get("https://data.eco-counter.com/public2/?id=100031235") # Sends an HTTP GET request to the target URL

# %%
print(response2.raise_for_status()) # Checks the status code of the HTTP response
# If the HTTP request was successful (i.e., the status code is in the 200–299 range), no exception information will be returned. 
# If the server returns an error code (i.e., the status code is 400 or above), raise_for_status() will raise an HTTPError.
# Out:
# None

# %%
html_content2 = response2.text #  get the body of the response, i.e., the HTML content of the page, as a string
soup2 = BeautifulSoup(html_content, 'html.parser') # parsing HTML content

# %%
soup2.find_all("script")
# Out:
# [<script src="js/vendor/modernizr-2.6.2.min.js"></script>,
#  <script src="js/vendor/jquery.min.js"></script>,
#  <script src="js/vendor/leaflet.js"></script>,
#  <script src="js/vendor/leaflet-plugins-1.2.1/layer/tile/Google.js"></script>,
#  <script src="js/vendor/jqplot/jquery.jqplot.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.barRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.categoryAxisRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.pointLabels.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.dateAxisRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.canvasTextRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.canvasAxisTickRenderer.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.highlighter.min.js"></script>,
#  <script src="js/vendor/jqplot/jqplot.cursor.min.js"></script>,
#  <script src="js/vendor/slidesjs/slides.min.jquery.js"></script>,
#  <script src="js/vendor/moment.min.js"></script>,
#  <script src="js/vendor/jquery.mousewheel.min.js"></script>,
#  <script src="js/vendor/jquery.mCustomScrollbar.js"></script>,
#  <script src="js/vendor/jquery.reveal.js"></script>,
#  <script src="js/vendor/jquery-ui.min.js"></script>,
#  <script src="js/vendor/jquery.daterangepicker.min.js"></script>,
#  <script src="js/vendor/highcharts.js"></script>,
#  <script src="js/plugins.js"></script>,
#  <script src="js/config.js"></script>,
#  <script src="js/main.min.js?t=1697100193690"></script>,
#  <script src="js/vendor/log.min.js"></script>,
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-6688181-5"></script>,
#  <script>
#  		  window.dataLayer = window.dataLayer || [];
#  		  function gtag(){dataLayer.push(arguments);}
#  		  gtag('js', new Date());
#
#  		  gtag('config', 'UA-6688181-5');
#  		</script>,
#  <script type="text/javascript">
#
#            var appName = "Parc publique";
#            var appVersion = "2.0";
#            // Initialisation de l'application, avec le nom et version de l'application
#            Log.init({
#                application: appName,
#                version_application: appVersion
#            });
#            // onLoad: enregistement de la visite
#            $(function(){
#                Log.startVisit({});
#            });
#  		</script>]
